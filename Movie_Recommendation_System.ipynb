# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv("tmdb_5000_movies.csv")
credits = pd.read_csv("tmdb_5000_credits.csv")
movies.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
# ...

# %%
credits.head(2)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...

# %%
# credits.head(1)['cast'].values
# movies.head(1)['genres'].values

# %%
# now we have two dataframes , we will merge these two dataframe on basis of similar column
movies = movies.merge(credits,on='title')
movies.head(1)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                       homepage     id  \
# 0  http://www.avatarmovie.com/  19995
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
#
#   original_title                                           overview  \
# 0         Avatar  In the 22nd century, a paraplegic Marine is di...
#
#    popularity                               production_companies  ...  \
# 0  150.437577  [{"name": "Ingenious Film Partners", "id": 289...  ...
#
#      status                      tagline   title vote_average vote_count  \
# 0  Released  Enter the World of Pandora.  Avatar          7.2      11800
#
#   Unnamed: 20 Unnamed: 21 movie_id  \
# 0         NaN         NaN    19995
#
#                                                 cast  \
# ...

# %%
# columns which we need to create tags


# movie_id
# title
# overview
# genres
# keywords
# cast
# crew
movies = movies[['movie_id','title','overview','genres','keywords','cast','crew']]
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# ...

# %%
movies.isnull().sum()  #check foe the missing data in any column
# Out:
# movie_id    0
# title       0
# overview    3
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
# we have 3 missing column in overview column , so just drop the column
movies.dropna(inplace = True)
movies.isnull().sum()
# Out:
# movie_id    0
# title       0
# overview    0
# genres      0
# keywords    0
# cast        0
# crew        0
# dtype: int64

# %%
# check for duplicate data
movies.duplicated().sum()
# Out:
# 0

# %%
movies.iloc[0].genres
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
# we are getting the object which is list of dictionary but in string format
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'
# desired format :  ['Action','Adventure','Fantasy','Science Fiction']

# %%
import ast

# %%
def convert(obj):
    L = []
    for i in ast.literal_eval(obj):
        tag = i['name']
        L.append(tag)
    return L

# %%
movies['genres'] = movies['genres'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
# we can use the same convert function to clean the column 'keywords'
movies['keywords'] = movies['keywords'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
# movies.iloc[0].cast
# we can use the same convert function to clean the column 'cast'
movies['cast'] = movies['cast'].apply(convert)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
# now we will clean the column crew
# we only fetch the name which contain the job = director

# %%
def fetch_director(text):
    List = []
    for i in ast.literal_eval(text):
        if i['job'] == 'Director':
            List.append(i['name'])
    return List

# %%
movies['crew']=movies['crew'].apply(fetch_director)
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
# now we have to clean the column 'overview' , convert the string into list of elements
movies['overview'] = movies['overview'].apply(lambda x:x.split())
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
# ...

# %%
# now we have to remove whitespace of tags, if user type sam then our model will might confuse which sam to show
# Sam Worthington => SamWorthington , Sam Mendes => SamMendes

# %%
movies['genres'] = movies['genres'].apply(lambda x:[i.replace(" ","") for i in x])
movies['keywords'] = movies['keywords'].apply(lambda x:[i.replace(" ","") for i in x])
movies['cast'] = movies['cast'].apply(lambda x:[i.replace(" ","") for i in x])
movies['crew'] = movies['crew'].apply(lambda x:[i.replace(" ","") for i in x])

movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
# ...

# %%
movies['tags'] = movies['overview']+movies['genres']+movies['keywords']+movies['cast']+movies['crew']  # bag of words

# %%
movies.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                             overview  \
# 0  [In, the, 22nd, century,, a, paraplegic, Marin...
# 1  [Captain, Barbossa,, long, believed, to, be, d...
# 2  [A, cryptic, message, from, Bond’s, past, send...
# 3  [Following, the, death, of, District, Attorney...
# 4  [John, Carter, is, a, war-weary,, former, mili...
#
#                                          genres  \
# 0  [Action, Adventure, Fantasy, ScienceFiction]
# 1                  [Adventure, Fantasy, Action]
# 2                    [Action, Adventure, Crime]
# 3              [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, ScienceFiction]
#
# ...

# %%
new_df = movies[['movie_id','title','tags']]
new_df
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4791      9367                               El Mariachi
# 4792     72766                                 Newlyweds
# 4793    231617                 Signed, Sealed, Delivered
# 4794    126186                          Shanghai Calling
# 4795     25975                         My Date with Drew
#
#                                                    tags
# 0     [In, the, 22nd, century,, a, paraplegic, Marin...
# 1     [Captain, Barbossa,, long, believed, to, be, d...
# 2     [A, cryptic, message, from, Bond’s, past, send...
# ...

# %%
new_df['tags'].apply(lambda x:" ".join(x))
# Out:
# 0       In the 22nd century, a paraplegic Marine is di...
# 1       Captain Barbossa, long believed to be dead, ha...
# 2       A cryptic message from Bond’s past sends him o...
# 3       Following the death of District Attorney Harve...
# 4       John Carter is a war-weary, former military ca...
#                               ...
# 4791    El Mariachi just wants to play his guitar and ...
# 4792    A newlywed couple's honeymoon is upended by th...
# 4793    "Signed, Sealed, Delivered" introduces a dedic...
# 4794    When ambitious New York attorney Sam is sent t...
# 4795    Ever since the second grade when he first saw ...
# Name: tags, Length: 4793, dtype: object

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))
# Out:
# /tmp/ipykernel_177519/3089450492.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x:" ".join(x))

# %%
new_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  In the 22nd century, a paraplegic Marine is di...
# 1  Captain Barbossa, long believed to be dead, ha...
# 2  A cryptic message from Bond’s past sends him o...
# 3  Following the death of District Attorney Harve...
# 4  John Carter is a war-weary, former military ca...

# %%
new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())
# Out:
# /tmp/ipykernel_177519/3214958533.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(lambda x:x.lower())

# %%
new_df.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 tags
# 0  in the 22nd century, a paraplegic marine is di...
# 1  captain barbossa, long believed to be dead, ha...
# 2  a cryptic message from bond’s past sends him o...
# 3  following the death of district attorney harve...
# 4  john carter is a war-weary, former military ca...

# %%
import nltk

from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    y=[]
    for i in text.split():              # text.split() converts the text into list
        y.append(ps.stem(i))

    return " ".join(y)

# %%
new_df['tags'] = new_df['tags'].apply(stem)
# Out:
# /tmp/ipykernel_177519/3213734980.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['tags'] = new_df['tags'].apply(stem)

# %%
 new_df['tags'][0]
# Out:
# 'in the 22nd century, a parapleg marin is dispatch to the moon pandora on a uniqu mission, but becom torn between follow order and protect an alien civilization. action adventur fantasi sciencefict cultureclash futur spacewar spacecoloni societi spacetravel futurist romanc space alien tribe alienplanet cgi marin soldier battl loveaffair antiwar powerrel mindandsoul 3d samworthington zoesaldana sigourneyweav stephenlang michellerodriguez giovanniribisi joeldavidmoor cchpounder wesstudi lazalonso dileeprao mattgerald seananthonymoran jasonwhyt scottlawr kellykilgour jamespatrickpitt seanpatrickmurphi peterdillon kevindorman kelsonhenderson davidvanhorn jacobtomuri michaelblain-rozgay joncurri lukehawk woodyschultz petermensah soniaye jahnelcurfman ilramchoi kylawarren lisaroumain debrawilson chrismala taylorkibbi jodielandau julielamm cullenb.madden josephbradymadden frankietorr austinwilson sarawilson tamicawashington-mil lucybri nathanmeist gerryblair matthewchamberlain paulyat wrayw
# ...

# %%
# now we will try to make vectors of all the tags in tags column
# we will use library sklearn and import CountVectorizer
# max_feature=5000  this indicates how many similar words we want , stop_words='english' -> ignores the english stop words

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000,stop_words='english')  # we will get 5000 most similar words from all the rows of tags column

# %%
vectors = cv.fit_transform(new_df['tags']).toarray()

# %%
# here we are converting it to numpy array because sklearn returns scipi sparse matrix

# %%
vectors.shape
# Out:
# (4793, 5000)

# %%
# we have 4806 movies and 5000 vectors

# %%
vectors[0]
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
# printing 100 features out of 5000
feature_names = cv.get_feature_names_out()
for feature in feature_names[:100]:
    print(feature)
# Out:
# 000
# 007
# 10
# 100
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18
# 18th
# 19
# 1930
# 1940
# 1950
# 1960
# 1960s
# 1970
# 1970s
# 1980
# 1990
# 19th
# 19thcenturi
# 20
# 20th
# 24
# 25
# 30
# 3d
# 40
# 50
# 60
# 70
# aaron
# aaroneckhart
# aarontaylor
# aasifmandvi
# abandon
# abduct
# abigailbreslin
# abil
# abl
# abov
# abus
# academi
# accept
# access
# accid
# accident
# accompani
# accomplish
# account
# accus
# ace
# achiev
# act
# action
# activ
# activist
# actor
# actress
# actual
# adam
# adambrodi
# adamgoldberg
# adamlefevr
# adamsandl
# adamscott
# adamshankman
# adapt
# add
# addict
# adewaleakinnuoye
# adjust
# admir
# admit
# adolesc
# adopt
# ador
# adrianmartinez
# adrienbrodi
# adult
# adulteri
# adulthood
# advanc
# adventur
# adventure
# advertis
# advic
# advis
# affair
# affect
# afghanistan
# africa
# african
# africanamerican
# aftercreditssting
# afterlif

# %%
# now we can see there are various similar features like accept , accepting , accepted etc 
# so we apply stemming of words => [accept , accepting , accepted] => after stemming => [accept, accept, accept]
# we will perform this operation above line 32   and re run the other steps after it

# %%
# now we will calculate cosine distance of each vector with every other vector of movies to calculate similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
cosine_similarity(vectors)
# Out:
# array([[1.        , 0.06818182, 0.07644708, ..., 0.04307305, 0.        ,
#         0.        ],
#        [0.06818182, 1.        , 0.07644708, ..., 0.02153652, 0.        ,
#         0.02272727],
#        [0.07644708, 0.07644708, 1.        , ..., 0.02414726, 0.        ,
#         0.        ],
#        ...,
#        [0.04307305, 0.02153652, 0.02414726, ..., 1.        , 0.04307305,
#         0.04307305],
#        [0.        , 0.        , 0.        , ..., 0.04307305, 1.        ,
#         0.09090909],
#        [0.        , 0.02272727, 0.        , ..., 0.04307305, 0.09090909,
#         1.        ]])

# %%
cosine_similarity(vectors).shape
# Out:
# (4793, 4793)

# %%
# total number of comparisions are 4806 x 4806

# %%
similarity = cosine_similarity(vectors)
similarity
# Out:
# array([[1.        , 0.06818182, 0.07644708, ..., 0.04307305, 0.        ,
#         0.        ],
#        [0.06818182, 1.        , 0.07644708, ..., 0.02153652, 0.        ,
#         0.02272727],
#        [0.07644708, 0.07644708, 1.        , ..., 0.02414726, 0.        ,
#         0.        ],
#        ...,
#        [0.04307305, 0.02153652, 0.02414726, ..., 1.        , 0.04307305,
#         0.04307305],
#        [0.        , 0.        , 0.        , ..., 0.04307305, 1.        ,
#         0.09090909],
#        [0.        , 0.02272727, 0.        , ..., 0.04307305, 0.09090909,
#         1.        ]])

# %%
similarity[0]   # it shows the similarity of first movie with all other 4806 movies
# Out:
# array([1.        , 0.06818182, 0.07644708, ..., 0.04307305, 0.        ,
#        0.        ])

# %%
# now we have to create a function which when user gives any one movie name then it gives or recomment the 5 similar movies

# %%
# to find the index of any movie 
movie_index = new_df[new_df['title']== 'Batman Begins'].index[0]
movie_index
# Out:
# 119

# %%
# defining index of each comparision of similarity matrices and sorting it on basis of comparision instead of index
sorted(list(enumerate(similarity[0])), reverse=True, key = lambda x:x[1])[1:6]
# Out:
# [(1210, 0.27028123880866767),
#  (581, 0.23354968324845687),
#  (2326, 0.23221018200641194),
#  (538, 0.22613350843332272),
#  (506, 0.22438727760202976)]

# %%
# creating a function
def recommend(movie):
    movie_index = new_df[new_df['title']== movie].index[0]
    # distances = similarity[movie_index]
    movies_list = sorted(list(enumerate(similarity[movie_index])), reverse=True, key = lambda x:x[1])[1:6]

    for i in movies_list:
        # print (i[0])
        print(new_df.iloc[i[0]].title)

# %%
recommend('Avatar')
# Out:
# Aliens vs Predator: Requiem
# Battle: Los Angeles
# Predator
# Titan A.E.
# Independence Day

# %%
import pickle
pickle.dump(new_df.to_dict(),open('movie_dict.pkl','wb'))

# %%
pickle.dump(similarity,open('similarity.pkl','wb'))

# %%
new_df
# Out:
#       movie_id                                     title  \
# 0        19995                                    Avatar
# 1          285  Pirates of the Caribbean: At World's End
# 2       206647                                   Spectre
# 3        49026                     The Dark Knight Rises
# 4        49529                               John Carter
# ...        ...                                       ...
# 4791      9367                               El Mariachi
# 4792     72766                                 Newlyweds
# 4793    231617                 Signed, Sealed, Delivered
# 4794    126186                          Shanghai Calling
# 4795     25975                         My Date with Drew
#
#                                                    tags
# 0     in the 22nd century, a parapleg marin is dispa...
# 1     captain barbossa, long believ to be dead, ha c...
# 2     a cryptic messag from bond’ past send him on a...
# ...

# %%
new_df.to_csv('final_dataframe.csv', index=False)

# %%
new_df.shape
# Out:
# (4793, 3)
